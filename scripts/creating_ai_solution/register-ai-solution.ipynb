# %% [markdown]
# ### **STEP-1**. 준비 작업
# &#x1F600; **등록 할 AI Contents 의 experimental_plan.yaml 를 alo/config/ 에 준비해 둡니다.**
#
# &#x1F600; **가상 환경을 만들어 두고, ipykernel 을 제작해 둡니다.**
#
# 1. ALO 의 main.py 파일이 존재하는 위치에서 아래 명령어들을 순차 실행합니다.
# > conda create -n {ENV-NAME} python=3.10 \
# > conda init bash \
# > conda activate {ENV-NAME} \
# > python main.py \
# > pip install ipykernel \
# > pip install requests \
# > python -m ipykernel install --user --name {ENV-NAME} --display-name {IPYKERNEL-NAME}
#
# 2. 본 jupyter notebook 에서, 위에서 생성한 ipykernel 을 선택 합니다. \
#    가령 tcr이라는 이름의 가상환경을 만들었다면, 아래와 같이 선택합니다.
#
# <div style="margin: 40px">
# <img src="./image/ipykernel.png" width="400">
# </div>

# %% [markdown]
# ----

# %% [markdown]
# ### **STEP-2**. Solution 정보 입력 및 Infra 정보 입력
#
# ##### Solution information (dict) 작성
# - inference_only: 파이프라인이 학습 및 추론 과정을 지원하는 표시
#   - ex1: 학습 과 추론 모두 지원 --> False
#   - ex2: 추론만 지원 --> True
#   - ex3: 학습 만은 미지원 --> ~~['train']~~
#
# - solution_update: 기존 솔루션을 업데이트 할지 결정
#   - True: 업데이트 진행. 기존 name 과 동일한 이름 입력 (name 이 존재하지 않으면 에러)
#   - False: 신규 생성. 기존 name 과 다르게 입력 (name 이 존재하면 에러)
#
# - solution_name: 솔루션 이름
#   - 주의사항: 스페이스, 특수 문자, 한글은 미지원
#
# - description: 솔루션이 Edge Conductor 의 UI 로 표시 될 때, 설명 가이드 작성
#   - overview: 솔루션에 대한 전반적을 설명을 작성. (markdown 을 지원)
#   - 고려사항: overview 외에 다양한 sub-title 지원 예정.
#
# - contents_type: re-train, re-labeling 을 위한 설명
#   - support_labeling: re-labeling 할지 결정. True 일 경우,
#     Edge Conductor 에서 re-labeling 기능 활성화.
#   - inference_result_datatype: EdgeApp 에 inference 결과를 표시하는 방법으로 'table', 'image' 중에 하나 선택.
#     AI Contents 제작 시, output.csv, output.jpg 를 생성해 두어야 함
#   - train_datatype: re-train 에 사용될 데이터 포멧 결정으로 'table', 'image' 중에 하나 선택.
#     AI Contents 제작 시, output.csv, output.jpg 를 생성해 두어야 함
#
# - train_gpu: True, False 중에 선택. True 일 경우, gpu 용 train docker container 제작
# - train_gpu: True, False 중에 선택. True 일 경우, gpu 용 inference docker container 제작
# - inference_arm: True, False 중에 선택. True 일 경우, arm 용 inference docker container 제작

# %%
#----------------------------------------#
#        AI Solution Spec 작성           #
#----------------------------------------#
solution_info ={
    'inference_only': False, # True, False
    'solution_update': True,
    'solution_name': 'tcr-test-ssh-v2',
    'description': {
        "overview": "Test TCR"
    },
    'contents_type': {
            'support_labeling': False,
            'inference_result_datatype': 'table', # 'image'
            'train_datatype': 'table' # 'image'
    },
    'train_gpu': True, ## cpu, gpu
    'inference_gpu': True,
    "inference_arm": True  # amd, arm  
}

# %% [markdown]
# ##### AI Solution 이 동작될 Infra (dict) 설정
# - AIC_URI: AI Conductor 또는 Solution Storage 의 web server 주소.
#   - 고객지수플랫폼: "https://aic-kic.aidxlge.com/"
#   - 마그나 운영과제: "https://aic-kic.aidxlge.com/"
#   - 담당테스트 환경: "http://10.158.2.243:9999/"
#   - 사외테스트 환경: "https://web.aic-dev.lgebigdata.com/"
#
# - REGION: AWS Cloud 의 region 값 ("ap-northeat-2" 고정)
# - WORKSPACE_NAME: 프로젝트 명을 의미.
#   (기술적의미: ML Ochestractor 의 물리적 태그 명으로 Cost 측정 단위)
#   - 고객지수플랫폼: "cism-ws"
#   - 마그나 운영과제: "magna-ws"
#   - 담당테스트 환경: "cism-ws", "magna-ws"
#   - 사외서비스 환경: "cism-ws", "magna-ws"
#
# - BUILD_METHOD: docker build 하는 방식 설정.
#   docker container 형태의 jupyter notebook 에서 솔루션 제작 시,
#   buildah (빌다) 라는 제작 방식을 사용해야 함.
#   - 고객지수플랫폼: "buildah"
#   - 마그나운영과제: "buildah"
#   - 담당테스트 환경 (솔루션 제작은 로컬서버 jupyter 실행): "docker"
#   - 사외서비스 환경 (솔루션 제작은 로컬서버 jupyter 실행): "docker"
#
# - VERSION: AI Solution 의 metadata 인 solution_metadata 의 format 버전.
#            AIC_URI 마다 지원버전이 다름.
#   - 모든 플랫폼 & 서비스 환경: 1.0 으로 동일
#
# - SOLUTION_TYPE: AI Solution 이 공유되는 계정 범위. 'private', 'public' 중에 하나 선택.
#   - 'public' : AI-Advisor 가 설치될 때, built-in 되어 설치 할 solution 의미.
#     (SYSTEM MANAGER 만 등록 가능)
#   - 'private': 과제 단위로 공유 될 solution.
#
# - REPOSITORY_TAGS: ECR repository 를 생성 시, 입력 할 Tags 값. 과금를 위한 표시 정보 (buildah 모드만 지원)
#   - 고객지수플랫폼, 마그나운영과제:
#     "REPOSITORY_TAGS": [
#       "Key=Company,Value=LGE",
#       "Key=Owner,Value=IC360",
#       "Key=HQ,Value=CDO",
#       "Key=Division,Value=CDO",
#       "Key=Infra Region,Value=KIC",
#       "Key=Service Mode,Value=OP",
#       "Key=Cost Type,Value=COMPUTING",
#       "Key=Project,Value=CIS",
#       "Key=Sub Project,Value=CISM",
#       "Key=System,Value=AIDX"]

# %%
infra_setup = {
    ### system info. 
    'AIC_URI': "https://web.aic-dev.lgebigdata.com/",  ## 실 서버 
    "REGION": "ap-northeast-2",
    "WORKSPACE_NAME": "cism-ws",  ## magna-ws, cism-ws
    "BUILD_METHOD": "docker",  ## docker, buildah 

    'VERSION': 1.0,
    "LOGIN_MODE": "static", ## ldap, static
    "ECR_TAG": "latest",   ## 없어질 사항
    "SOLUTION_TYPE": "private", ##public, private 
    "REPOSITORY_TAGS": [ 
      "Key=Company,Value=LGE",
      "Key=Owner,Value=IC360",
      "Key=HQ,Value=CDO",
      "Key=Division,Value=CDO",
      "Key=Infra Region,Value=KIC",
      "Key=Service Mode,Value=OP",
      "Key=Cost Type,Value=COMPUTING",
      "Key=Project,Value=CIS",
      "Key=Sub Project,Value=CISM",
      "Key=System,Value=AIDX"]
}

# %% [markdown]
# ### **STEP-3**. AI Solution 등록
#
# ##### 3-1. Username & Password 를 입력
#
# > !! 접속이 실패되는 경우, AI Conductor 에게 계정 생성을 요청 하시기 바랍니다.
# > Contact Us: hyunsoo0802.lim@lge.com  (LGE AI빅데이터담당, AI Conductor 담당자)
#
# > Login 방식이 {'LOGIN_METHOD': 'ldap'} 로 설정되어 있는 경우, LGEP 의 ID & PW 를 사용

# %%
import getpass

username = input('Username: ')
password = getpass.getpass('Password: ')

print("Your ID : ", username)
print("Your PW : ", password.replace(password, '*' * len(password)))
# Out:
# Your ID :  cism-dev
# Your PW :  ************

# %% [markdown]
# ##### 3-2. ALO 솔루션 등록 실행
# 아래와 같은 과정이 순차적으로 실행 됨. 진행 중 Error 가 발생하게 되면, STEP-2 설정을 변경 함.
# > Contact US: sehyun.song@lge.com (LGE AI빅데이터 담당, ALO 담당자)
#
# AI Solution 등록 과정 Process:
# > 1.  solution name 입력
# > 2.  description & wrangler code 를 solution_metadata 에 삽입
# > 3.  contents_type 을 solution_metadata 에 삽입
# > 4.  description 의 solution icon 을 solution_metadata 에 삽입
# > 5.  train 용 user parameter 를 solution_metadata 에 삽입
# > 6.  s3 에 train data & artifacts 업로드
# > 7.  train 용 ecr repository 생성 및 docker container 업로드
# > 8.  inference 용 user parameter 를 solution_metadata 에 삽입
# > 9.  s3 에 inference data & artifacts 업로드
# > 10. inference 용 ecr repository 생성 및 docker container 업로드
# > 11. solution 등록

# %%
import sys
from IPython.display import SVG, display, HTML
import os 
from solution_register import SolutionRegister

try:
    del sys.modules['solution_register'] 
except:
    pass

register = SolutionRegister(
    infra_setup=infra_setup, 
    solution_info=solution_info)

register.debugging = True  ## default: False (skip 항목: docker 생성, solution 등록)
register.skip_generation_docker = False  ## default: False
register.run(username=username, password=password)
# Out:
# ######################################################
# #######    Initiate ALO operation mode
# ########################################################
#
# [SYSTEM] Solutoin 등록에 필요한 setup file 들을 load 합니다.
# [SYSTEM] infra_setup (max display: 5 line):
# {'AIC_URI': 'https://web.aic-dev.lgebigdata.com/',
#  'BUILD_METHOD': 'docker',
#  'ECR_TAG': 'latest',
#  'LOGIN_MODE': 'static',
#  'REGION': 'ap-northeast-2',
#  'REPOSITORY_TAGS': ['Key=Company,Value=LGE',
#                      'Key=Owner,Value=IC360',
#                      'Key=HQ,Value=CDO',
#                      'Key=Division,Value=CDO',
#                      'Key=Infra Region,Value=KIC',
#                      'Key=Service Mode,Value=OP',
#                      'Key=Cost Type,Value=COMPUTING',
#                      'Key=Project,Value=CIS',
#                      'Key=Sub Project,Value=CISM',
#                      'Key=System,Value=AIDX'],
#  'SOLUTION_TYPE': 'private',
#  'VERSION': 1.0,
#  'WORKSPACE_NAME': 'cism-ws'}
#
# API setup 파일이 존재 하지 않으므로, Default 파일을 load 합니다. (path: ./api_setup.yaml)
# [SYSTEM] solution_info. (max display: 5 line):
# {'contents_type': {'inference_result_datatype': 'table',
#                    'support_labeling': False,
#                    'train_datatype': 'table'},
#  'description': {'algorithm': '',
#                  'input_data': '',
#                  'output_data': '',
#                  'overview': 'Test TCR',
#                  'title': 'tcr-test-ssh-v2',
#                  'user_parameters': ''},
#  'inference_arm': True,
#  'inference_gpu': True,
#  'name': 'tcr-test-ssh-v2',
#  'pipeline_type': ['train', 'inference'],
#  'solution_update': True,
#  'train_gpu': True}
# [SYSTEM] S3 key 파일을 로드 합니다. (file: /nas001/users/ruci.sung/aws.key)
#
# ######################################################
# #######    Solution Name Creation
# ########################################################
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/sehyun.song/Project/alo/dev-240111/scripts/creating_ai_solution/1-1-2-register-ai-solution.ipynb 셀 10 line 1
#      <a href='vscode-notebook-cell://ssh-remote%2B10.158.2.41/home/sehyun.song/Project/alo/dev-240111/scripts/creating_ai_solution/1-1-2-register-ai-solution.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> register.debugging = True  ## default: False (skip 항목: docker 생성, solution 등록)
#      <a href='vscode-notebook-cell://ssh-remote%2B10.158.2.41/home/sehyun.song/Project/alo/dev-240111/scripts/creating_ai_solution/1-1-2-register-ai-solution.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> register.skip_generation_docker = False  ## default: False
# ---> <a href='vscode-notebook-cell://ssh-remote%2B10.158.2.41/home/sehyun.song/Project/alo/dev-240111/scripts/creating_ai_solution/1-1-2-register-ai-solution.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> register.run(username=username, password=password)
#
# File ~/Project/alo/dev-240111/scripts/creating_ai_solution/solution_register.py:141, in SolutionRegister.run(self, username, password)
#     131 def run(self, username, password):
#     132
#     133     #############################
#    (...)
#     139     ###  Solution Name 입력
#     140     #############################
# --> 141     self.check_solution_name()
#     143     self.load_system_resource()   ## ECR, S3 정보 받아오기
#     144     self._init_solution_metadata()
#
# File ~/Project/alo/dev-240111/scripts/creating_ai_solution/solution_register.py:270, in SolutionRegister.check_solution_name(self, name)
#     267 self.print_step("Solution Name Creation")
#     269 if not name:
# --> 270     name = self.solution_info['solution_name']
#     272 # 231207 임현수C: 사용자는 public 사용못하게 해달라
#     273 ONLY_PUBLIC = 1 #1 --> 1로 해야 public, private 다 받아옴
#
# KeyError: 'solution_name'

# %% [markdown]
# ##### 등록된 AI Solution 테스트 하기

# %%
try:
    del sys.modules['solution_register'] 
except:
    pass

from solution_register import SolutionRegister

register2 = SolutionRegister(
    infra_setup=infra_setup, 
    solution_info=solution_info)
    
register2.login(username, password)
register2.register_solution_instance()
register2.load_solution_instance_list()
register2.register_stream()
register2.request_run_stream()
status = register2.get_stream_status()
print(status)

# artifacts = register2.download_artifacts()
# Out:
# ######################################################
# #######    Initiate ALO operation mode
# ########################################################
#
# [SYSTEM] Solutoin 등록에 필요한 setup file 들을 load 합니다.
# [SYSTEM] infra_setup (max display: 5 line):
# {'AIC_URI': 'https://web.aic-dev.lgebigdata.com/',
#  'BUILD_METHOD': 'docker',
#  'ECR_TAG': 'latest',
#  'LOGIN_MODE': 'static',
#  'REGION': 'ap-northeast-2',
#  'REPOSITORY_TAGS': ['Key=Company,Value=LGE',
#                      'Key=Owner,Value=IC360',
#                      'Key=HQ,Value=CDO',
#                      'Key=Division,Value=CDO',
#                      'Key=Infra Region,Value=KIC',
#                      'Key=Service Mode,Value=OP',
#                      'Key=Cost Type,Value=COMPUTING',
#                      'Key=Project,Value=CIS',
#                      'Key=Sub Project,Value=CISM',
#                      'Key=System,Value=AIDX'],
#  'SOLUTION_TYPE': 'private',
#  'VERSION': 1.0,
#  'WORKSPACE_NAME': 'cism-ws'}
#
# API setup 파일이 존재 하지 않으므로, Default 파일을 load 합니다. (path: ./api_setup.yaml)
# [SYSTEM] solution_info. (max display: 5 line):
# {'contents_type': {'inference_result_datatype': 'table',
#                    'support_labeling': False,
#                    'train_datatype': 'table'},
#  'description': {'algorithm': '',
#                  'input_data': '',
#                  'output_data': '',
#                  'overview': 'Test TCR',
#                  'title': 'tcr-test-ssh-v2',
#                  'user_parameters': ''},
#  'inference_arm': True,
#  'inference_gpu': True,
#  'name': 'tcr-test-ssh-v2',
#  'pipeline_type': ['train', 'inference'],
#  'solution_update': True,
#  'train_gpu': True}
# [SYSTEM] S3 key 파일을 로드 합니다. (file: /nas001/users/ruci.sung/aws.key)
#
# ######################################################
# #######    Login to AI Conductor
# ########################################################
#
# 해당 계정으로 접근 가능한 workspace list: ['cism-ws']
# [SYSTEM] 접근 요청하신 workspace (cism-ws) 은 해당 계정으로 접근 가능합니다.
#
# ######################################################
# #######    Register AI solution instance
# ########################################################
#
# [SYSTEM] AI solution 등록 정보를 ./interface/.response_solution.json 에서 확인합니다.
#
# [INFO] AI solution interface information:
#  {'workspace_name': 'cism-ws'}
# [ERROR] AI solution instance 등록을 실패하였습니다. 잘못된 요청입니다.
# Error message:  app.handlers.instances_v1_0 : Failed to create Instance, already exist name tcr-test-ssh-v2
#
# ######################################################
# #######    Load AI solution instance list
# ########################################################
#
# [SYSTEM] AI solution 등록 정보를 ./interface/.response_solution.json 에서 확인합니다.
#
# [INFO] AI solution interface information:
#  {'workspace_name': 'cism-ws'}
# [SUCCESS] AI solution instance 등록을 성공하였습니다.
# '[INFO] response: '
# (idx: 0), instance_name: instance-hyunsoo-cism-create-2, instance_id: 22c66856-090a-4c4d-9531-1676ac977c77
# (idx: 1), instance_name: instance-hyunsoo-cism-1, instance_id: 3b17e6c7-2f9a-4eb0-8c70-092b29fa008f
# (idx: 2), instance_name: instance test 2, instance_id: 444002dc-2a01-46a2-bb0f-9df587d2e6e0
# (idx: 3), instance_name: pytest-instance-12, instance_id: 5508a98e-32df-4c80-bf57-45a536186e50
# (idx: 4), instance_name: instance-hyunsoo-cism-20, instance_id: 5b910fd9-0a1f-46f3-82bc-6e75ad7451be
# (idx: 5), instance_name: tcr-test-ssh, instance_id: 71212d31-d9ad-432b-9095-99c68029bc51
# (idx: 6), instance_name: instance test 1, instance_id: 7831cb9b-f206-464f-848d-0e8d5da30c9d
# (idx: 7), instance_name: pytest-instance-1, instance_id: 7a013de1-1d90-4971-ba89-2690648efaca
# (idx: 8), instance_name: instance test 5, instance_id: 7bd8ce2f-dff8-4a0d-b93a-7befe9a95044
# (idx: 9), instance_name: tcr-test-swj3, instance_id: 7d7dad0e-7cb5-4024-9cec-66722c378752
# (idx: 10), instance_name: hyunsoo-test~~~~~~~~~~~~~~2, instance_id: 7e46982d-f9fe-4adc-9ae1-55781f116feb
# (idx: 11), instance_name: toy solution, instance_id: 9b6cb231-2a00-4a63-a9f6-df9295dda84f
# (idx: 12), instance_name: instance-hyunsoo-cism-2, instance_id: b0c6818d-5484-43c3-8f16-0df4b272f373
# (idx: 13), instance_name: instance test 3, instance_id: b0e85212-58a9-4895-af8f-f3e188859e47
# (idx: 14), instance_name: instance-hyunsoo-upload-30, instance_id: b5b90e59-135b-4914-a722-91e65456906b
# (idx: 15), instance_name: tcr-test-swj2, instance_id: c3c92798-12ed-4c40-a447-1db7a21e9328
# (idx: 16), instance_name: tcr-test-ssh-v2, instance_id: c50c7819-7ca7-4919-9295-13892062f028
# (idx: 17), instance_name: instance test 4, instance_id: ca6a103e-94de-4647-bba2-a692dcc2ecd0
# (idx: 18), instance_name: instance-hyunsoo-cism-create-1, instance_id: df95821c-b80f-46be-bcfd-640fe369ec53
# [SYSTEM] register 결과를 ./interface/.response_instance_list.json 에 저장합니다.
#
# ######################################################
# #######    Request AI solution stream run
# ########################################################
#
# [SYSTEM] Stream 등록 정보를 ./interface/.response_stream.json 에서 확인합니다.
# {'stream_id': '48101dd4-44c7-4e36-9e25-5a70f32e2c50',
#  'workspace_name': 'cism-ws'}
# [SUCCESS] Stream Run 요청을 성공하였습니다.
# [INFO] response:
#  {'id': 'bbab5b06-6708-4fdf-87fe-09faea1df1ab', 'name': 'tcr-test-ssh-v2-20240122061155', 'workspace_name': 'cism-ws', 'stream_id': '48101dd4-44c7-4e36-9e25-5a70f32e2c50', 'train_pipeline_id': '9bd067ec-b6dc-4cb2-a6d0-a678618d3c3e', 'status': 'running', 'train_dataset_uri': ['s3://s3-an2-hyunsoo-dev-cism/ai-solutions/tcr-test-ssh-v2/v1/train/data/'], 'train_artifact_uri': 's3://s3-an2-hyunsoo-dev-cism/instances/tcr-test-ssh-v2/48101dd4-44c7-4e36-9e25-5a70f32e2c50/train/artifacts/2024/01/22/061155.405/', 'model_version': '0', 'is_deleted': 0, 'created_at': '2024-01-22T06:11:55', 'updated_at': '2024-01-22T06:11:55'}
# [SYSTEM] register 결과를 ./interface/.response_stream_run.json 에 저장합니다.
#
# ######################################################
# #######    Get AI solution stream status
# ########################################################
#
# [SYSTEM] Stream 실행 정보를 ./interface/.response_stream_run.json 에서 확인합니다.
# [SUCCESS] Stream Status 요청을 성공하였습니다.
# [INFO] response:
#  {'id': 'bbab5b06-6708-4fdf-87fe-09faea1df1ab', 'name': 'tcr-test-ssh-v2-20240122061155405', 'workspace_name': 'cism-ws', 'stream_id': '48101dd4-44c7-4e36-9e25-5a70f32e2c50', 'train_pipeline_id': '9bd067ec-b6dc-4cb2-a6d0-a678618d3c3e', 'status': 'running', 'train_dataset_uri': [], 'train_artifact_uri': 's3://s3-an2-hyunsoo-dev-cism/instances/tcr-test-ssh-v2/48101dd4-44c7-4e36-9e25-5a70f32e2c50/train/artifacts/2024/01/22/061155.405/', 'model_version': '0', 'is_deleted': 0, 'created_at': '2024-01-22T06:11:55', 'updated_at': '2024-01-22T06:11:55'}
# [SYSTEM] status 확인 결과를 ./interface/.response_stream_status.json 에 저장합니다.
# running

# %%
# 가상환경이 잘 connected 돼있는지 확인 
# !which python 
# 현재 작업경로 확인 
# !pwd

# s3로부터 다운로드받은 train artifacts를 scripts 폴더 상위 경로의 main.py랑 같은 위치로 옮기고 추론 실행 
import os
os.makedirs("./.train_artifacts",  exist_ok=True)

# !tar -xvf ./train_artifacts.tar.gz -C ./.train_artifacts/
# !cp -r .train_artifacts ../../
# !rm -rf ./.train_artifacts

# !python ../../main.py --mode inference

# %% [markdown]
# ##### 테스트 용 solution_instance & stream 삭제 하기
# - 옵션: solution 삭제 진행

# %%
try:
    del sys.modules['solution_register'] 
except:
    pass

from solution_register import SolutionRegister

register3 = SolutionRegister(
    infra_setup=infra_setup, 
    solution_info=solution_info)
    
register3.login(username, password)
register3.delete_stream()
register3.delete_solution_instance()
register3.delete_solution()
# Out:
# ######################################################
# #######    Initiate ALO operation mode
# ########################################################
#
# [SYSTEM] Solutoin 등록에 필요한 setup file 들을 load 합니다.
# [SYSTEM] infra_setup (max display: 5 line):
# {'AIC_URI': 'https://web.aic-dev.lgebigdata.com/',
#  'BUILD_METHOD': 'docker',
#  'ECR_TAG': 'latest',
#  'LOGIN_MODE': 'static',
#  'REGION': 'ap-northeast-2',
#  'REPOSITORY_TAGS': ['Key=Company,Value=LGE',
#                      'Key=Owner,Value=IC360',
#                      'Key=HQ,Value=CDO',
#                      'Key=Division,Value=CDO',
#                      'Key=Infra Region,Value=KIC',
#                      'Key=Service Mode,Value=OP',
#                      'Key=Cost Type,Value=COMPUTING',
#                      'Key=Project,Value=CIS',
#                      'Key=Sub Project,Value=CISM',
#                      'Key=System,Value=AIDX'],
#  'SOLUTION_TYPE': 'private',
#  'VERSION': 1.0,
#  'WORKSPACE_NAME': 'cism-ws'}
#
# API setup 파일이 존재 하지 않으므로, Default 파일을 load 합니다. (path: ./api_setup.yaml)
# [SYSTEM] solution_info. (max display: 5 line):
# {'contents_type': {'inference_result_datatype': 'table',
#                    'support_labeling': False,
#                    'train_datatype': 'table'},
#  'description': {'algorithm': '',
#                  'input_data': '',
#                  'output_data': '',
#                  'overview': 'Test TCR',
#                  'title': 'tcr-test-ssh-v2',
#                  'user_parameters': ''},
#  'inference_arm': True,
#  'inference_gpu': True,
#  'name': 'tcr-test-ssh-v2',
#  'pipeline_type': ['train', 'inference'],
#  'solution_update': True,
#  'train_gpu': True}
# [SYSTEM] S3 key 파일을 로드 합니다. (file: /nas001/users/ruci.sung/aws.key)
#
# ######################################################
# #######    Login to AI Conductor
# ########################################################
#
# 해당 계정으로 접근 가능한 workspace list: ['cism-ws']
# [SYSTEM] 접근 요청하신 workspace (cism-ws) 은 해당 계정으로 접근 가능합니다.
#
# ######################################################
# #######    Delete stream
# ########################################################
#
# [SYSTEM] Strema 등록 정보를 ./interface/.response_stream.json 에서 확인합니다.
# [ERROR] Stream 삭제를 실패하였습니다. 잘못된 요청입니다.
# Error message:  app.handlers.repository_v1_0 : Failed to delete Stream History Not found path : s3://s3-an2-hyunsoo-dev-cism/instances/tcr-test-ssh-v2/48101dd4-44c7-4e36-9e25-5a70f32e2c50/train/artifacts/2024/01/22/061155.405/
#
# ######################################################
# #######    Delete AI solution instance
# ########################################################
#
# [SYSTEM] AI solution instance 등록 정보를 ./interface/.response_solution_instance.json 에서 확인합니다.
# [ERROR] AI solution insatnce 삭제를 실패하였습니다. 잘못된 요청입니다.
# Error message:  app.handlers.instances_v1_0 : Failed to delete Instance, Stream exist ['tcr-test-ssh-v2']
#
# ######################################################
# #######    Delete AI solution
# ########################################################
#
# [SYSTEM] AI solution 등록 정보를 ./interface/.response_solution.json 에서 확인합니다.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/sehyun.song/Project/alo/dev-240111/scripts/creating_ai_solution/1-1-2-register-ai-solution.ipynb 셀 16 line 1
#      <a href='vscode-notebook-cell://ssh-remote%2B10.158.2.41/home/sehyun.song/Project/alo/dev-240111/scripts/creating_ai_solution/1-1-2-register-ai-solution.ipynb#X63sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> register3.delete_stream()
#      <a href='vscode-notebook-cell://ssh-remote%2B10.158.2.41/home/sehyun.song/Project/alo/dev-240111/scripts/creating_ai_solution/1-1-2-register-ai-solution.ipynb#X63sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> register3.delete_solution_instance()
# ---> <a href='vscode-notebook-cell://ssh-remote%2B10.158.2.41/home/sehyun.song/Project/alo/dev-240111/scripts/creating_ai_solution/1-1-2-register-ai-solution.ipynb#X63sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> register3.delete_solution()
#
# File ~/Project/alo/dev-240111/scripts/creating_ai_solution/solution_register.py:1716, in SolutionRegister.delete_solution(self)
#    1711     raise ValueError(f"[ERROR] {path} 를 읽기 실패 하였습니다.")
#    1713 # stream 등록
#    1714 stream_params = {
#    1715     "solution_id": response_solution['id'],
# -> 1716     "workspace_name": response_solution['workspace_name']
#    1717 }
#    1719 aic = self.infra_setup["AIC_URI"]
#    1720 api = self.api_uri["REGISTER_SOLUTION"] + f"/{response_solution['id']}"
#
# KeyError: 'workspace_name'
